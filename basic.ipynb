# %%
import numpy as np
import pandas as pd

# %%
info = {
    "Name" : ["Rahul", "Harshita", "Alex"],
    "CGPA" : [9.7,7.8,9.8]
}

df = pd.DataFrame(info)
print(df)
# Out:
#        Name  CGPA
# 0     Rahul   9.7
# 1  Harshita   7.8
# 2      Alex   9.8

# %%
srs = pd.Series([1,2,3,4,5],index=["d1","d2","d3","d4","d5"])
print(srs["d4"])
# Out:
# 4

# %%
srs = srs * 2
srs
# Out:
# d1     8
# d2    16
# d3    24
# d4    32
# d5    40
# dtype: int64

# %%
changed_srs = srs.drop("d1")
changed_srs
# Out:
# d2    16
# d3    24
# d4    32
# d5    40
# dtype: int64
