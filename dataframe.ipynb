# %%
import pandas as pd

data = {
    "Name": ["Lalit", "Rohan", "Aman"],
    "Age": [21, 22, 20],
    "Marks": [85, 90, 78]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Marks
# 0  Lalit   21     85
# 1  Rohan   22     90
# 2   Aman   20     78
